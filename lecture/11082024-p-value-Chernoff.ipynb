# %%
# First, load any modules you need here.

import numpy as np
from matplotlib import pyplot as plt
from matplotlib import colors as colors

import scipy.linalg as scipy_linalg

import scipy.optimize as optimize

import scipy.integrate as integrate

import scipy.stats as scipy_stats

import scipy.special as special

# %% [markdown]
# ## Hypothesis testing and P-value
#
# <h3>
#
# The rest of the semester, we're going to look more at some statistics.
#
# We often have some data and we want to see if we have a result that is significant.  We call this hypothesis testing.
#
# For example, we may give paitents a drug to see if they live longer.  (We propably also want to know how much longer, but first we just want to see if there is any effect.)
#
# We might have a correlation between exposure to a chemical and cancer rates, and we want to know is that correlation significant?
#
# We might give students a pre- and post- test to see if they learned anything in a class.  Are the score different?
#
#
# We've seen some of this already, when we talked about linear fitting and function fitting, and about how good a fit was.  Also a little when comparing different fits.  But let's take a look where we really just want to test a hypothesis.  We'll start with a coin.  We want to figure out if the coin is fair or biased.
#
# In this case, our null hypothesis is that the coin if fair, the probability of being heads is $p=0.5$.  We can test this against an alternate hypothesis that $p \ne 0.5$.
#
# We saw before that coin flips will follow what's called a binomial distribution - each flip is a random trial with probability $p$ of producing a head.  So for n flips, the probability of getting X number of heads is Binomial(n,p):
#
# </h3>

# %%
# Example of a binomial distribution:

n = 50

p=0.5

x = np.arange(n+1)

y1 = scipy_stats.binom.pmf(x,n,p)

p = 0.4

y2 = scipy_stats.binom.pmf(x,n,p)


plt.plot(x,y1,'o')
plt.plot(x,y2,'o')
#plt.yscale('log')
plt.show()

# %% [markdown]
# <h3>
#
# This looks very close to a normal Gaussian distribution with an average of $mu = p$ and a standard deviation of $sigma = \sqrt{p*(1-p)*n}$.
#
# </h3>

# %%
def normal_approximation_to_binomial(n,p):
    mu = p * n
    sigma = np.sqrt(p * (1-p) * n)
    return(mu,sigma)

def normal(x,mu,sigma):
    norm = 1/(sigma*np.sqrt(2*np.pi)) * np.exp(-(x-mu)**2/(2*sigma**2))
    return(norm)

n =1000

p = 0.5

x = np.arange(n+1)

y1 = scipy_stats.binom.pmf(x,n,p)


mu,sigma = normal_approximation_to_binomial(n,p)

print(mu,sigma)

#norm_y1 = 1/(sigma*np.sqrt(2*np.pi)) * np.exp(-(x-mu)**2/(2*sigma**2))
norm_y1 = normal(x,mu,sigma)


p = 0.2

y2 = scipy_stats.binom.pmf(x,n,p)

mu,sigma = normal_approximation_to_binomial(n,p)

#norm_y2 = 1/(sigma*np.sqrt(2*np.pi)) * np.exp(-(x-mu)**2/(2*sigma**2))
norm_y2 = normal(x,mu,sigma)


plt.plot(x,y1,'o')
plt.plot(x,norm_y1)
plt.plot(x,y2,'o')
plt.plot(x,norm_y2,'*')
#plt.yscale('log')
plt.show()

plt.plot(x,np.abs(1-y1/norm_y1))
plt.yscale('log')
plt.show()
# Out:
# 500.0 15.811388300841896

# %% [markdown]
# <h3>
#
# Doesn't look to bad.  we'll need the cumulative distribution functions as well.  For a normal distrubtions we ca ndefine this.  For the binomial distribution we'll use the built-in CDF.
#
# For a given location, the CDF tells us what fraction of the function is at or below that value.
#
# </h3>

# %%
# Need cumulative distribution functions:

def normal_cdf(x,mu,sigma):
    cdf = (1 + special.erf((x - mu) / (np.sqrt(2) * sigma))) / 2.
    return(cdf)

# Normal approximiation
norm_cdf_y2 = normal_cdf(x,mu,sigma)

# Using build-in function:
cdf_y2 = scipy_stats.binom.cdf(x,n,p)

# We could also do this by addinf up the dsitribution by hand:
by_hand_cdf = np.cumsum(y2)

plt.plot(cdf_y2,'o')
plt.plot(norm_cdf_y2)
plt.plot(by_hand_cdf,'r*')
plt.show()

plt.plot(cdf_y2-norm_cdf_y2)
plt.plot(cdf_y2-by_hand_cdf)
plt.show()

# %% [markdown]
# <h3>
#
# Now we can use the CDF to find the below of above some threshold or in some interval.
#
# The CDF is the probability the variable is below a given threshold.
#
# </h3>

# %%
p=0.2

def prob_below(lo,n,p):
    return(scipy_stats.binom.cdf(lo,n,p))

# if not below, it's above.
def prob_above(lo,n,p):
    return(1-prob_below(lo,n,p))

# probabilty in interval
def prob_between(lo,hi,n,p):
    return(scipy_stats.binom.cdf(hi,n,p) - scipy_stats.binom.cdf(lo,n,p))

# probability outside interval
def prob_outside(lo,hi,n,p):
    return(1-prob_between(lo,hi,n,p))

print('n,p = ',n,p)
print('prob_between(8,12,n,p) = ',prob_between(8,12,n,p))

# Also set up the inverse of the CDF.  This finds the value for a given probability.
# Also called the PPF - percent point function

# Here prob (or more) fraction is below the returned value
def upper_bound(prob,n,p):
    return(scipy_stats.binom.ppf(prob,n,p))

# 1-prob (or more) fraction is below the given value
def lower_bound(prob,n,p):
    return(scipy_stats.binom.ppf(1-prob,n,p)-1)

print('upper_bound(0.99,n,p) = ',upper_bound(0.99,n,p))
print('upper_bound(0.01,n,p) = ',upper_bound(0.01,n,p))
print('lower_bound(0.99,n,p) = ',lower_bound(0.99,n,p))
print(x[12],cdf_y2[12])

# At least (1-prob)/2 is in the tail outside the two bounds
def two_sided_bounds_outer(prob,n,p):
    tail_probability = (1-prob)/2
    upper = lower_bound(tail_probability,n,p)
    lower = upper_bound(tail_probability,n,p)
    return(lower,upper)

def two_sided_bounds(prob,n,p):
    tail_probability = (1-prob)/2
    upper = lower_bound(tail_probability,n,p)+1
    lower = upper_bound(tail_probability,n,p)-1
    return(lower,upper)


print('Two-sidede bound for prob=0.9 are ',two_sided_bounds(.9,n,p))
print('Values are ',cdf_y2[5],cdf_y2[15])
print('probability between = ',cdf_y2[15]-cdf_y2[5])
# Out:
# n,p =  1000 0.2
# prob_between(8,12,n,p) =  1.505452842219316e-77
# upper_bound(0.99,n,p) =  230.0
# upper_bound(0.01,n,p) =  171.0
# lower_bound(0.99,n,p) =  170.0
# 12 1.5054575191566118e-77
# Two-sidede bound for prob=0.9 are  (178.0, 221.0)
# Values are  1.0114153092292635e-87 8.392829297340953e-74
# probability between =  8.392829297340852e-74

# %% [markdown]
# ## Coin flip examples
#
# <h3>
#
# Now let look at determining if a coin is fair.
#
# First, let's say we do 1,000 coin flips.  What is the range of outcomes for head we expect?   What bound can we put so that only 5% or outcomes are outside those bounds?
#
# </h3>

# %%
n = 1000

p = 0.5

x = np.arange(n+1)

y50 = scipy_stats.binom.pmf(x,n,p)

cdf_y50 = scipy_stats.binom.cdf(x,n,p)

plt.plot(x,y50)
plt.show()


# What is the 95% range for outcomes?

lower,upper = two_sided_bounds(.95,n,p)
lower50 = int(lower)
upper50 = int(upper)

print('The bounds are',lower50,upper50)
print('Values are ',cdf_y50[lower50],cdf_y50[upper50])
print('Ranger between values is ',cdf_y50[upper50]-cdf_y50[lower50])
#print('One step lower and high, values are ',cdf_y[lower-1],cdf_y[upper+1])
# Out:
# The bounds are 468 531
# Values are  0.023145598680249003 0.976854401319751
# Ranger between values is  0.953708802639502

# %% [markdown]
# <h3>
#
# Only about 5% of the time do you have less 468 heads or more than 531.
#
# Now we want to see what happens if our coin is biased.  Let's say our coin come up heads 55% of the time.  What does the distribution look like?
#
# </h3>

# %%
p = 0.55

y55 = scipy_stats.binom.pmf(x,n,p)

cdf_y55 = scipy_stats.binom.cdf(x,n,p)

plt.plot(x,y50)
plt.plot(x,y55)
plt.show()


# What is the 95% range for outcomes?

lower,upper = two_sided_bounds(.95,n,p)
lower55 = int(lower)
upper55 = int(upper)

print('The bounds are',lower55,upper55)
print('Values are ',cdf_y55[lower55],cdf_y55[upper55])
print('Ranger between values is ',cdf_y55[upper55]-cdf_y55[lower55])
#print('One step lower and high, values are ',cdf_y[lower-1],cdf_y[upper+1])

print(' ')

# How often will the biased coin fall in the 95% range of the fair coin?

prob_looks_fair = prob_between(lower50,upper50,n,p)

print('Probability the 55% coin looks fair = ',prob_looks_fair)
print('Probability the coin is rejected as not fiar = ',1-prob_looks_fair)
# Out:
# The bounds are 518 581
# Values are  0.02277177668344545 0.9775713230973402
# Ranger between values is  0.9547995464138948
#
# Probability the 55% coin looks fair =  0.11988283650568078
# Probability the coin is rejected as not fiar =  0.8801171634943192

# %% [markdown]
# <h3>
#
# So there's about an 88% chance that a coin with a 55% heads probability will look unfiar after 1000 flips, compared to only 5% for a fair coin.
#
#
# </h3>

# %% [markdown]
# ## P-value
#
# <h3>
#
# What we want to do now is say we see a certain number of heads.  What is the probability that the coin is fair?  This is called the p-value.
#
# You are often looking for a p-value < 0.05 or < 0.01 to reject a null hypothesis
#
# Keep in mind, if you do 20 trials, you should get 1 with a p-value < 0.05.  This diesn't mean you found something - it means you p-value isn't high enough.  Called p-hacking.
#
# </h3>

# %%
# 

def two_sided_p_value(x,n,p):
    if x >= p*n:
        # value is greater than the mean
        return(2 * prob_above(x,n,p))
    else:
        return(2 * prob_below(x,n,p))

# for 530 heads:

print('530 p-value =',two_sided_p_value(529.5,1000,0.5))

# Use 529.5 to get probabilty of at least 530 heads showing up.


# for 540 heads:

print('540 p-value =',two_sided_p_value(539.5,1000,0.5))


# for 532 heads puts you at p < 0.05:

print('532 p-value =',two_sided_p_value(531.5,1000,0.5))


# for 542 heads, p<0.01 :

print('542 p-value =',two_sided_p_value(541.5,1000,0.5))



# for 553 heads, p<0.001 :

print('553 p-value =',two_sided_p_value(552.5,1000,0.5))
# Out:
# 530 p-value = 0.062023195098363404
# 540 p-value = 0.01244414627717183
# 532 p-value = 0.046291197360498026
# 542 p-value = 0.008639949002260394
# 553 p-value = 0.000889985964769302

# %% [markdown]
# ## Confidence Interval
#
# <h3>
#
# We can also turn this around - for a given number of heads we observe in a given number of flips, what is the range values for the probability of hte coin being heads to we get?
#
# This is called the confidence interval.  Usually we want something like the 95% or 99% confidence interval.
#
# Let's set this up.
#
# The easiest thing to do is approximate our distribution as a gaussian, and then the confidence interval is easy.
#
# Our probability is assumed to be head over flips, which is mu in our Gaussian, and our width sigma is $\sqrt{p(1-p)/n}$
#
# We can do a little better (maybe?) using the full binomial distribution.  We assume p is head/n, and find the confidence interval from out two-sided bounds:
#
# </h3>

# %%
# Calculate confidence interval:

# For 530 heads:

heads = 530

confidence_interval = np.asarray(two_sided_bounds(0.95,n,heads/n))/n
confidence_interval99 = np.asarray(two_sided_bounds(0.99,n,heads/n))/n

print('For',heads,'heads the 95% confidence interval is', confidence_interval)
print('For',heads,'heads the 99% confidence interval is', confidence_interval99)

print(' ')

heads = 540

confidence_interval = np.asarray(two_sided_bounds(0.95,n,heads/n))/n
confidence_interval99 = np.asarray(two_sided_bounds(0.99,n,heads/n))/n

print('For',heads,'heads the 95% confidence interval is', confidence_interval)
print('For',heads,'heads the 99% confidence interval is', confidence_interval99)
# Out:
# For 530 heads the 95% confidence interval is [0.498 0.561]
# For 530 heads the 99% confidence interval is [0.488 0.571]
#
# For 540 heads the 95% confidence interval is [0.508 0.571]
# For 540 heads the 99% confidence interval is [0.498 0.581]

# %% [markdown]
# <h3>
#
# 530 heads does not rule out a fair coin at the 95% or 99% confidence level.
#
# 540 heads does rule out a fiar coin at the 95% level, but not 99% level.  0.5 (fair) is still in the 99% confidence interval.
#
#
# </h3>

# %% [markdown]
# <br>
# <br>
#
#
# # Start here 11/8/2024
#
# <br>
#
#
# ## How many trials do I need?
#
# <h3>
#
# How many trials does it take to decide if your coin is not fair, or if there is a signal in your data?  It depends on the size of the effect you're looking for, and the significance level you want to find.
#
# Let's say after n flip (trials) I want a 95% chance that the number of heads will not be consistent with a fair coin, $p=0.5$.
#
# How unfair would the coin have to be for this to happen?
#
# Let's also say that being "unfair" means that $p=0.5$ is not in the 95% confidence interval.  But we could use different values.  Maybe we want to be really sure the coin is "fair" to with 5% or 1%, say to 5-sigma.  Or maybe we want to be really sure it's fair (to within a part in a million) but only the the 95% confidence level.
#
# I had to look up how to do this, but we can use what are called Chernoff bounds.  Here we are using them in additive form.
#
# They tell us the probability that the number of heads divided by number of flips will be more than the expected value (p) plus some amout (delta).  Delta is the limit on how "fair" the coin is.
#
# $P(|1/n * \sum(X_i)| > p+delta) ≤ 2*e^{[−n (delta^2)/(2 p (1-p))]}$
#
# (The factor of two is because the number of heads could be high or low.)
#
# We can then set this probability equal to how confident we want to be that the coin is at least this fair.  Or, put another way, how likely are we to be able to determine the coin is unfiar if the true probability is off by at least delta?  We'll call this value epsilon.
#
# Set the probability equal to epsilon, and solve for n:
#
# $epsilon = 2*e^{[−n (delta^2)/(2 p (1-p))]}$
#
# $\ln(epsilon) = \frac{2p(1-p)}{n (delta^2)} * \ln(2)$
#
# $n = \frac{2p(1-p)}{delta^2} * \ln(\frac{2}{epsilon})$
#
# </h3>

# %%
# Finding how many flips are needed

# Sources:

# https://www.reddit.com/r/askscience/comments/90s854/supposing_i_have_an_unfair_coin_not_5050_but_dont/?rdt=33811
# https://en.wikipedia.org/wiki/Chernoff_bound#Sums_of_independent_Bernoulli_random_variables
# https://math.mit.edu/~goemans/18310S15/chernoff-notes.pdf


# With additive error


n = 1000

p = 0.5


# Chernoff bounds

def Chernoff_prob(n,p,delta):
    # This calculates the Chernoff bounds for the combined upper and lower tails.
    # P(1/n * sum(X_I) > p+delta) ≤ e^[−n*(delta^2)/(2*p*(1-p))]
    # Need a facor of 2 for high and low (p+delta and p-delta).

    
    prob = 2*np.exp(-(n * (delta**2)) / (2*p*(1-p)))
    return(prob)

test = Chernoff_prob(n,p,0.1)

print(test)

print(' ')

def Chernoff_trials(p,delta,epsilon):
    # delta is the accuracy we want
    # epsilon is the probbility of obtaining the accuracy

    # We want the probability to equal epsilon for n trials

    # epsilon = 2*e^[−n*(delta^2)/(2*p*(1-p))]

    # ln(epsilon) = 2*p*(1-p) / (n*delta^2) * ln(2)

    # n = 2*p*(1-p)/(delta^2) * ln(2/epsilon)

    n = 2*p*(1-p)/(delta**2) * np.log(2/epsilon)

    return(n)

delta = 0.1
epsilon = 0.01

test_n = Chernoff_trials(p,delta,epsilon)

print('For a p of',p,'with delta =',delta,'and epsilon =',epsilon,'you need n =',test_n,'trials')

#print(Chernoff_prob(test_n,p,0.1))

# Use my 2-sided bounds to check the confidence interval
# And use check that the Chernoff probability is equal to epsilon

lower,upper = two_sided_bounds(1-delta,int(test_n),p)
lower50 = int(lower)
upper50 = int(upper)

print('You expect heads/n to be between',lower50/test_n,'and',upper50/test_n,'for a fair coin')
print('Probability of being between n-delta and n+delta heads is',Chernoff_prob(test_n,p,delta))

#lower,upper = two_sided_bounds(1-epsilon,int(test_n),p-delta)
#lower50 = int(lower)
#upper50 = int(upper)
#
#x = np.arange(int(test_n)+1)
#y50 = scipy_stats.binom.pmf(x,int(test_n),p)
#cdf_y50 = scipy_stats.binom.cdf(x,int(test_n),p)
#
#print('The bounds are',lower50/test_n,upper50/test_n)
#print('Values are ',cdf_y50[lower50],cdf_y50[upper50])
#print('Ranger between values is ',cdf_y50[upper50]-cdf_y50[lower50])

print(' ')

delta = 0.05
epsilon = 0.05

test_n = Chernoff_trials(p,delta,epsilon) #*.06

print('For a p of',p,'with delta =',delta,'and epsilon =',epsilon,'you need n =',test_n,'trials')

#print(Chernoff_prob(test_n,p,0.1))

lower,upper = two_sided_bounds(1-delta,int(test_n),p)
lower50 = int(lower)
upper50 = int(upper)

print('You expect heads/n to be between',lower50/test_n,'and',upper50/test_n,'for a fair coin')
#print('Values are ',cdf_y50[lower50],cdf_y50[upper50])
#print('Ranger between values is ',cdf_y50[upper50]-cdf_y50[lower50])
#print('One step lower and high, values are ',cdf_y[lower-1],cdf_y[upper+1])
print('Probability of being between n-delta and n+delta heads is',Chernoff_prob(test_n,p,delta))
# Out:
# 4.122307244877101e-09
#
# For a p of 0.5 with delta = 0.1 and epsilon = 0.01 you need n = 264.91586832740177 trials
# You expect heads/n to be between 0.4454244313299015 and 0.5473435808714892 for a fair coin
# Probability of being between n-delta and n+delta heads is 0.010000000000000004
#
# For a p of 0.5 with delta = 0.05 and epsilon = 0.05 you need n = 737.7758908227871 trials
# You expect heads/n to be between 0.46219997731249773 and 0.5353929355965883 for a fair coin
# Probability of being between n-delta and n+delta heads is 0.05

# %% [markdown]
# <h3>
#
# How about really strict limits?  Let's say I want to "discover" the coin is unfair at some level to 5-sigma:
#
# </h3>

# %%
# For 5% or more unfair

delta = 0.05
epsilon = 5.7e-7  # 5-sigma

test_n = Chernoff_trials(p,delta,epsilon) #*.06

print('For a p of',p,'with delta =',delta,'and epsilon =',epsilon,'you need n =',test_n,'trials')

#print(Chernoff_prob(test_n,p,0.1))

lower,upper = two_sided_bounds(1-delta,int(test_n),p)
lower50 = int(lower)
upper50 = int(upper)

print('You expect heads/n to be between',lower50/test_n,'and',upper50/test_n,'for a fair coin')
#print('Values are ',cdf_y50[lower50],cdf_y50[upper50])
#print('Ranger between values is ',cdf_y50[upper50]-cdf_y50[lower50])
#print('One step lower and high, values are ',cdf_y[lower-1],cdf_y[upper+1])
print('Probability of being between n-delta and n+delta heads is',Chernoff_prob(test_n,p,delta))


print(' ')

# For 1% or more unfair

delta = 0.01
epsilon = 5.7e-7  # 5-sigma

test_n = Chernoff_trials(p,delta,epsilon) #*.06

print('For a p of',p,'with delta =',delta,'and epsilon =',epsilon,'you need n =',test_n,'trials')

#print(Chernoff_prob(test_n,p,0.1))

lower,upper = two_sided_bounds(1-delta,int(test_n),p)
lower50 = int(lower)
upper50 = int(upper)

print('You expect heads/n to be between',lower50/test_n,'and',upper50/test_n,'for a fair coin')
#print('Values are ',cdf_y50[lower50],cdf_y50[upper50])
#print('Ranger between values is ',cdf_y50[upper50]-cdf_y50[lower50])
#print('One step lower and high, values are ',cdf_y[lower-1],cdf_y[upper+1])
print('Probability of being between n-delta and n+delta heads is',Chernoff_prob(test_n,p,delta))


print(' ')

# For 0.1% or more unfair

delta = 1.e-3
epsilon = 5.7e-7  # 5-sigma

test_n = Chernoff_trials(p,delta,epsilon) #*.06

print('For a p of',p,'with delta =',delta,'and epsilon =',epsilon,'you need n =',test_n,'trials')

#print(Chernoff_prob(test_n,p,0.1))

lower,upper = two_sided_bounds(1-delta,int(test_n),p)
lower50 = int(lower)
upper50 = int(upper)

print('You expect heads/n to be between',lower50/test_n,'and',upper50/test_n,'for a fair coin')
#print('Values are ',cdf_y50[lower50],cdf_y50[upper50])
#print('Ranger between values is ',cdf_y50[upper50]-cdf_y50[lower50])
#print('One step lower and high, values are ',cdf_y[lower-1],cdf_y[upper+1])
print('Probability of being between n-delta and n+delta heads is',Chernoff_prob(test_n,p,delta))
# Out:
# For a p of 0.5 with delta = 0.05 and epsilon = 5.7e-07 you need n = 3014.1553313355516 trials
# You expect heads/n to be between 0.48172699824220033 and 0.5178896999008779 for a fiar coin
# Probability of being between n-delta and n+delta heads is 5.699999999999995e-07
#
# For a p of 0.5 with delta = 0.01 and epsilon = 5.7e-07 you need n = 75353.8832833888 trials
# You expect heads/n to be between 0.49528967020373 and 0.5046853372768836 for a fiar coin
# Probability of being between n-delta and n+delta heads is 5.699999999999995e-07
#
# For a p of 0.5 with delta = 0.001 and epsilon = 5.7e-07 you need n = 7535388.32833888 trials
# You expect heads/n to be between 0.4994005399625588 and 0.5005992837573582 for a fiar coin
# Probability of being between n-delta and n+delta heads is 5.700000000000006e-07
